# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <img src='net.png'>

# %%
X=np.random.randn(50,2)

# %%
data=pd.DataFrame(X)

# %%
data
# Out:
#            0         1
# 0  -0.828869 -0.143277
# 1  -0.836023 -0.147487
# 2  -0.943959 -1.082995
# 3  -0.816997 -1.723620
# 4  -0.431048 -0.712274
# 5   1.609323 -0.071237
# 6   0.374929 -0.274387
# 7   0.232187  0.365756
# 8   0.690511  2.475666
# 9  -0.485479 -0.529454
# 10  0.228327 -1.654768
# 11 -0.504157 -0.898609
# 12  0.051940  0.318419
# 13 -1.860541 -1.228023
# 14  0.431786 -1.016970
# 15 -0.740845 -0.811606
# 16  1.975239 -0.667291
# 17 -0.243570  0.720541
# 18 -0.671667  0.039680
# 19  0.427471 -0.836591
# 20 -0.239797  0.252356
# 21 -0.119861 -0.166686
# 22  0.327434 -0.556938
# 23  0.241826 -0.549850
# 24 -0.627383  0.794487
# 25 -1.539935 -0.813705
# 26  0.194592 -0.042818
# 27 -0.563503  1.117096
# 28  1.003368 -1.593344
# 29  0.498906 -2.082903
# 30  0.484962  0.380832
# 31  0.422447  0.569730
# 32 -0.262363  1.552471
# 33 -0.546967 -0.942304
# 34  1.176930  0.805404
# 35  0.358591 -0.328680
# 36 -0.446069  0.579158
# 37  0.588714 -0.024958
# 38 -0.439377  0.375395
# 39 -0.696432 -0.736338
# 40 -2.360017 -0.050072
# 41  0.752107 -1.748438
# 42 -0.413548 -1.000807
# 43  1.025150  0.816488
# 44  0.736282  0.336820
# 45 -0.176478  0.627275
# 46 -0.356053 -0.203800
# 47 -0.061946  0.422645
# 48  0.170736 -0.438345
# 49  1.563906 -0.493068

# %%
data.columns=['X1','X2']

# %%
data
# Out:
#           X1        X2
# 0  -0.828869 -0.143277
# 1  -0.836023 -0.147487
# 2  -0.943959 -1.082995
# 3  -0.816997 -1.723620
# 4  -0.431048 -0.712274
# 5   1.609323 -0.071237
# 6   0.374929 -0.274387
# 7   0.232187  0.365756
# 8   0.690511  2.475666
# 9  -0.485479 -0.529454
# 10  0.228327 -1.654768
# 11 -0.504157 -0.898609
# 12  0.051940  0.318419
# 13 -1.860541 -1.228023
# 14  0.431786 -1.016970
# 15 -0.740845 -0.811606
# 16  1.975239 -0.667291
# 17 -0.243570  0.720541
# 18 -0.671667  0.039680
# 19  0.427471 -0.836591
# 20 -0.239797  0.252356
# 21 -0.119861 -0.166686
# 22  0.327434 -0.556938
# 23  0.241826 -0.549850
# 24 -0.627383  0.794487
# 25 -1.539935 -0.813705
# 26  0.194592 -0.042818
# 27 -0.563503  1.117096
# 28  1.003368 -1.593344
# 29  0.498906 -2.082903
# 30  0.484962  0.380832
# 31  0.422447  0.569730
# 32 -0.262363  1.552471
# 33 -0.546967 -0.942304
# 34  1.176930  0.805404
# 35  0.358591 -0.328680
# 36 -0.446069  0.579158
# 37  0.588714 -0.024958
# 38 -0.439377  0.375395
# 39 -0.696432 -0.736338
# 40 -2.360017 -0.050072
# 41  0.752107 -1.748438
# 42 -0.413548 -1.000807
# 43  1.025150  0.816488
# 44  0.736282  0.336820
# 45 -0.176478  0.627275
# 46 -0.356053 -0.203800
# 47 -0.061946  0.422645
# 48  0.170736 -0.438345
# 49  1.563906 -0.493068

# %%
w1=0.4
w2=0.5
w3=0.2
w4=0.35
w5=0.45
w6=0.25

# %%
Output1 = w1*data.X1+w3*data.X2

# %%
Output1
# Out:
# 0    -0.360203
# 1    -0.363907
# 2    -0.594182
# 3    -0.671523
# 4    -0.314874
# 5     0.629482
# 6     0.095094
# 7     0.166026
# 8     0.771338
# 9    -0.300082
# 10   -0.239623
# 11   -0.381384
# 12    0.084460
# 13   -0.989821
# 14   -0.030680
# 15   -0.458659
# 16    0.656638
# 17    0.046680
# 18   -0.260731
# 19    0.003670
# 20   -0.045448
# 21   -0.081281
# 22    0.019586
# 23   -0.013240
# 24   -0.092056
# 25   -0.778715
# 26    0.069273
# 27   -0.001982
# 28    0.082678
# 29   -0.217018
# 30    0.270151
# 31    0.282925
# 32    0.205549
# 33   -0.407248
# 34    0.631853
# 35    0.077701
# 36   -0.062596
# 37    0.230494
# 38   -0.100672
# 39   -0.425840
# 40   -0.954021
# 41   -0.048845
# 42   -0.365581
# 43    0.573358
# 44    0.361877
# 45    0.054864
# 46   -0.183181
# 47    0.059751
# 48   -0.019375
# 49    0.526949
# dtype: float64

# %%
Output1 = sum(Output1)

# %%
Output1
# Out:
# -2.8623714830834874

# %%
#Activation
def sigmoid(n):
    return 1/(1+np.exp(-n))

# %%
#Outputs from the hidden layer
X11 = sigmoid(Output1)

# %%
X22 = sigmoid(sum(w2*data.X1+w4*data.X2))

# %%
target= sigmoid(w5*X11+w6*X22)

# %%
target
# Out:
# 0.506654252873043

# %%
wh1=1
wh2=2
wh3=3
wh4=2.5
wh5=2
wh6=1.5

# %%
def meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6):
    return ((target-(wh5*sigmoid(sum(wh1*data.X1+wh3*data.X2))+wh6*sigmoid(sum(wh2*data.X1+wh4*data.X2))))*(target-(wh5*sigmoid(sum(wh1*data.X1+wh3*data.X2))+wh6*sigmoid(sum(wh2*data.X1+wh4*data.X2)))))/2

# %%
meansquarederr(1,2,3,2.5,2,1.5)
# Out:
# 0.12834926597713925

# %%
Learning_Rate = 0.005
Epsilon = 0.00001

# %%
def partialder_Wh1():
    return (meansquarederr(wh1+Epsilon,wh2,wh3,wh4,wh5,wh6)-meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6))/Epsilon

# %%
def partialder_Wh2():
    return (meansquarederr(wh1,wh2+Epsilon,wh3,wh4,wh5,wh6)-meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6))/Epsilon

# %%
def partialder_Wh3():
    return (meansquarederr(wh1,wh2,wh3+Epsilon,wh4,wh5,wh6)-meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6))/Epsilon

# %%
def partialder_Wh4():
    return (meansquarederr(wh1,wh2,wh3,wh4+Epsilon,wh5,wh6)-meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6))/Epsilon

# %%
def partialder_Wh5():
    return (meansquarederr(wh1,wh2,wh3,wh4,wh5+Epsilon,wh6)-meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6))/Epsilon

# %%
def partialder_Wh6():
    return (meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6+Epsilon)-meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6))/Epsilon

# %%
partialder_Wh1()
# Out:
# 0.0

# %%
partialder_Wh2()
# Out:
# 0.0

# %%
count = 0
err = meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6)
while(True):
    wh1=w1-(Learning_Rate)*partialder_Wh1()
    wh2=w2-(Learning_Rate)*partialder_Wh2()
    wh3=w3-(Learning_Rate)*partialder_Wh3()
    wh4=w4-(Learning_Rate)*partialder_Wh4()
    wh5=w5-(Learning_Rate)*partialder_Wh5()
    wh6=w6-(Learning_Rate)*partialder_Wh6()
    print(wh1,wh2,wh3,wh4,wh5,wh6)
    count=count+1
    print(err)
    if (err-meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6)<=0.0000001):
        break
    err = meansquarederr(wh1,wh2,wh3,wh4,wh5,wh6)
# Out:
# 0.4 0.5 0.2 0.3499999999999861 0.450103976250207 0.2500215357800065
# 0.12834926597713925
# 0.3999091342720928 0.49999100778793476 0.19939123207143983 0.34993978192643765 0.4501305175269528 0.250022071353932
# 0.11521432958532207
# 0.3999086022418604 0.4999910047375276 0.19938774438703466 0.34993974303928027 0.45013052173724466 0.2500220713212498
# 0.11513690798027253
# 0.39990859921223526 0.49999100475041314 0.19938772454115972 0.3499397430147513 0.4501305217633835 0.2500220713210278
# 0.11513647057337785

# %%
wh5
# Out:
# 0.4501305217633835
